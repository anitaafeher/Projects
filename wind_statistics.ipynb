# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %% [markdown]
# ```
# Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
# 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.
# ````

# %% [markdown]
#   The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv('wind.csv')
df = pd.DataFrame(data)

df['Date'] = df.apply(lambda x: f"{int(x['Yr'])}-{int(x['Mo'])}-{int(x['Dy'])}", axis=1) #strings together the first 3 cols
df['Date'] = pd.to_datetime(df['Date'], format='%y-%m-%d') #converts to date
df = df.drop(['Yr', 'Mo', 'Dy'], axis=1) #drops the first 3 cols 
first_col = df.pop('Date')
df.insert(0, 'Date', first_col) #makes Date the first column
df
# Out:
#            Date    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %% [markdown]
# ### Step 2. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def year_correction(date):
    if date.year > 1989:
        date = date.replace(year=date.year -100)
    return date

wrong_dates = df['Date'].apply(lambda x: x.year > 1989).sum()
print(f"Count of the wrong dates: {wrong_dates}")
df['Date'] = df['Date'].apply(year_correction)
print(df)
# Out:
# Count of the wrong dates: 2922
#            Date    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# ### Step 3. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
df['Date'] = pd.to_datetime(df['Date']) #making sure it is date type
df.set_index('Date', inplace=True)
print(df)
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# ...

# %% [markdown]
# ### Step 4. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
nan_values = df.isna().sum()
print(f"Summary of the missing values by location:\n{nan_values}")
# Out:
# Summary of the missing values by location:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 5. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
average_windspeed = df.stack().mean()
rounded_average = round(average_windspeed, 2)
print(f"Average windspeed over all locations: {rounded_average}")
# Out:
# Average windspeed over all locations: 10.23

# %% [markdown]
# ### Step 6. Create a DataFrame called stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
stats = pd.DataFrame(data)
stats = df.describe()
stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %%
wind_min = df.min()
wind_max = df.max()
wind_mean = df.mean()
wind_std = df.std()
wind_count = df.count()
stats = pd.DataFrame({
    'min': wind_min,
    'max': wind_max,
    'mean': wind_mean,
    'std': wind_std,
    'count': wind_count
})
wind_stats = stats.transpose()
wind_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
#
#                BIR          DUB          CLA          MUL          CLO  \
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# max      26.160000    30.370000    31.080000    25.880000    28.210000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
#
#                BEL          MAL
# min       0.130000     0.670000
# max      42.380000    42.540000
# ...

# %% [markdown]
# ### Step 7. Create a DataFrame called dailywind and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
dailywind = pd.DataFrame(data)
dailywind = df.describe()
dailywind
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %%
dailywind['min'] = df.min(axis=1)
dailywind['max'] = df.max(axis=1)
dailywind['mean'] = df.mean(axis=1)
dailywind['std'] = df.std(axis=1)

dailywind
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %% [markdown]
# ### Step 8. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
#ensuring the datetime format 
df.index = pd.to_datetime(df.index)

january_data = df[df.index.month == 1]
average_january_windspeed = january_data.mean()

average_january_windspeed
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 9. Downsample the record to a yearly frequency for each location.

# %%
df.index = pd.to_datetime(df.index)
yearly_data = df.resample('YE').mean()

yearly_data
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# ### Step 10. Downsample the record to a weekly frequency for each location.

# %%
df.index = pd.to_datetime(df.index)
weekly_data = df.resample('W-MON').mean()

weekly_data
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1961-01-02  14.875000  14.960000  12.000000   7.895000  12.620000   8.770000
# 1961-01-09  13.237143  11.392857  10.368571   6.167143   9.152857   6.310000
# 1961-01-16  13.017143   9.027143  12.768571   4.624286   7.490000   5.091429
# 1961-01-23  13.221429   9.678571  13.392857   7.150000   9.326667   8.238571
# 1961-01-30  19.158333  16.350000  17.137143  12.357143  17.372857  14.392857
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-04  15.054286  12.232857  13.798571   5.571429  10.828571   9.547143
# 1978-12-11  22.215714  20.000000  18.551429  11.194286  16.257143  13.612857
# 1978-12-18  15.270000  13.508571  13.654286   5.398571  10.152857   6.220000
# 1978-12-25  10.781429   7.394286  13.077143   4.242857   7.212857   6.087143
# 1979-01-01  16.241667  12.671667  17.403333   7.146667  10.471667   9.293333
#
# ...

# %% [markdown]
# ### Step 11. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
df.index = pd.to_datetime(df.index)
weekly_data = df.resample('W-MON', origin='1961-01-02').agg(['min', 'max', 'mean', 'std'])
weekly_data_52 = weekly_data.iloc[:52]

weekly_data_52
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Date
# 1961-01-02  14.71  15.04  14.875000  0.233345  14.96  14.96  14.960000
# 1961-01-09  10.58  18.50  13.237143  2.596592   6.63  16.88  11.392857
# 1961-01-16   9.04  19.75  13.017143  3.858751   3.54  12.08   9.027143
# 1961-01-23   4.92  19.83  13.221429  5.349631   3.42  14.37   9.678571
# 1961-01-30  12.21  25.04  19.158333  5.499583  11.17  23.91  16.350000
# 1961-02-06  10.58  24.50  18.582857  5.499102   9.46  24.21  16.792857
# 1961-02-13  16.00  24.54  19.398571  3.198809  11.54  21.42  16.267143
# 1961-02-20   6.04  17.08  13.492857  4.032186  11.08  20.17  13.860000
# 1961-02-27   7.79  25.80  15.215714  7.024701   7.08  21.50  13.952857
# 1961-03-06   4.88  13.33  11.227143  2.931380   8.08  17.00  12.195714
# 1961-03-13   6.46  14.79  10.431667  3.036837   8.33  16.96  12.044286
# ...
